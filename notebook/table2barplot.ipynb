# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


SMALL_SIZE = 14
MEDIUM_SIZE = 14
BIGGER_SIZE = 18

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=MEDIUM_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)

# %%
df = pd.read_csv("../tests/exp1.csv")
# df.drop('Seq', inplace=True, axis=1)
methods = df.columns
df
# Out:
#              Seq  Original  Proposed processing  Histogram Equalization  \
# 0      00 shaded       178                  292                     282
# 1      01 shaded        60                  215                     274
# 2      02 shaded        94                  158                     265
# 3      03 shaded       101                  253                     275
# 4   04 semi-dark       114                  262                     272
# 5   05 semi-dark        92                  205                     267
# 6   06 semi-dark        59                  208                     272
# 7   07 semi-dark       105                  309                     301
# 8   08 semi-dark        83                  173                     253
# 9        09 dark        91                  177                     258
# 10       10 dark        76                  165                     255
# 11       11 dark        37                  133                     247
# ...

# %%
# df = df.transpose()
df = df.set_index("Seq")

# %%
# fig, ax = plt.subplots(figsize=(16, 8))
colors =  ['twilight', 'twilight_shifted', 'hsv']

for c in colors:
    print("COLOR:", c)
    ax = df.plot.bar(rot=45, figsize=(16, 4), fontsize=14, ylabel="Avg. number of features", cmap=c) #x=df.index, y=df.columns[1:],rot=0) , xlabel=''
    ax.legend(loc="center", bbox_to_anchor=(1.13, 0.5)) #, fancybox=True, shadow=True)
    # plt.savefig('../images/exp1_bar2.png', bbox_inches='tight')
    plt.show()
# Out:
# COLOR: twilight
# COLOR: twilight_shifted
# COLOR: hsv

# %%
fig = plt.figure()
ax = df.plot.bar(rot=20, figsize=(16, 4), fontsize=14, ylabel="Avg. number of features") #x=df.index, y=df.columns[1:],rot=0) , xlabel=''
# ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.16), ncol=4)
ax.legend(loc='center', bbox_to_anchor=(1.13 , 0.5))
plt.savefig('../images/exp1_bar.png', bbox_inches='tight')

# %%
df
# Out:
#           speed  lifespan
# snail       0.1       2.0
# pig        17.5       8.0
# elephant   40.0      70.0
# rabbit     48.0       1.5
# giraffe    52.0      25.0
# coyote     69.0      12.0
# horse      88.0      28.0

# %%
speed = [0.1, 17.5, 40, 48, 52, 69, 88]

lifespan = [2, 8, 70, 1.5, 25, 12, 28]

index = ['snail', 'pig', 'elephant',

         'rabbit', 'giraffe', 'coyote', 'horse']

df = pd.DataFrame({'speed': speed,

                   'lifespan': lifespan}, index=index)

ax = df.plot.bar(rot=0)
